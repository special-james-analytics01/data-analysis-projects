# %% [markdown]
# # Sales Data Analysis Using Pandas
#
# ## Objective
# The objective of this project is to analyze sales data using Python and Pandas in order to identify trends, patterns, and overall business performance.
#
# ## Dataset Description
# The dataset contains sales records including information such as products, quantities sold, prices, and dates. The data was used to understand sales behavior and performance over time.
#
# ## Tools Used
# - Python
# - Pandas
# - Jupyter Notebook
#
# ## Data Cleaning
# Data cleaning steps included handling missing values, correcting data types, and removing any inconsistencies to ensure accurate analysis.
#
# ## Exploratory Data Analysis (EDA)
# Exploratory analysis was performed using tables and basic visualizations to identify trends, high-performing products, and sales patterns.
#
# ## Key Insights
# - Certain products recorded higher sales volumes than others
# - Sales trends showed variations across different time periods
# - Cleaned data improved accuracy of the analysis
#
# ## Conclusion
# This analysis provided useful insights into sales performance and demonstrated how Pandas can be used effectively for data analysis tasks.

# %%
import pandas as pd

print("pandas is working")

# %% [markdown]
# # Pandas Project: Sales Data Analysis

# %%
## Project Overview
This project analyzes sales data using pandas to uncover trends,
total sales, and basic insights.

Tools used:
- Python
- Pandas
- Jupyter Notebook

# %%
import pandas as pd

data = {
    "Product": ["Phone", "Laptop", "Tablet", "Phone", "Laptop"],
    "Revenue": [200000, 500000, 150000, 180000, 520000]
}

df = pd.DataFrame(data)
df

# %%
df.groupby("Product")["Revenue"].sum()
